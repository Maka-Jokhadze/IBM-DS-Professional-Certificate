# %%
import pandas as pd
data=pd.read_csv('happyscore_income.csv')

# %%
happy=data['happyScore']
income=data['avg_income']
ineq=data['income_inequality']
print(happy)
# Out:
# 0      4.350
# 1      4.033
# 2      6.574
# 3      7.200
# 4      7.284
#        ...
# 106    6.485
# 107    5.360
# 108    4.642
# 109    5.129
# 110    4.610
# Name: happyScore, Length: 111, dtype: float64

# %%
happy.min()
# Out:
# 2.839

# %%
happy.max()
# Out:
# 7.587

# %%
income.min()
# Out:
# 572.88

# %%
income.max()
# Out:
# 26182.275

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(income,happy)
plt.xlabel('income')
plt.ylabel('happy score')
# Out:
# Text(0, 0.5, 'happy score')

# %%
data
# Out:
#           country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0         Armenia                     37               4.9              2.42
# 1          Angola                     26               4.3              3.19
# 2       Argentina                     60               7.1              1.91
# 3         Austria                     59               7.2              2.11
# 4       Australia                     65               7.6              1.80
# ..            ...                    ...               ...               ...
# 106       Uruguay                     58               7.0              2.13
# 107       Vietnam                     53               6.1              1.77
# 108  South Africa                     49               6.3              2.47
# 109        Zambia                     37               5.0              2.61
# 110      Zimbabwe                     33               4.1              2.16
#
# ...

# %%
#data.sort_values('avg_income',inplace=True)
data.sort_values('avg_satisfaction',inplace=True)
data.head(111)
# Out:
#           country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 102      Tanzania                     19               2.5              2.26
# 97           Togo                     22               2.6              2.08
# 10        Burundi                     25               2.9              1.96
# 11          Benin                     20               3.0              2.70
# 93   Sierra Leone                     27               3.5              2.36
# ..            ...                    ...               ...               ...
# 77         Norway                     70               8.0              1.62
# 48        Iceland                     71               8.1              1.64
# 70         Mexico                     69               8.3              2.02
# 27        Denmark                     74               8.4              1.53
# 22     Costa Rica                     73               8.5              1.71
#
# ...

# %%
richest=data[data['avg_income']>15000]
richest
# Out:
#             country  adjusted_satisfaction  avg_satisfaction  \
# 49            Italy                     57               6.6
# 44          Ireland                     64               7.5
# 90           Sweden                     67               7.8
# 36   United Kingdom                     60               7.1
# 7           Belgium                     63               7.2
# 33          Finland                     70               7.9
# 27          Denmark                     74               8.4
# 34           France                     52               6.4
# 76      Netherlands                     69               7.6
# 48          Iceland                     71               8.1
# 25          Germany                     61               7.2
# 3           Austria                     59               7.2
# 4         Australia                     65               7.6
# 16           Canada                     69               8.0
# ...

# %%
richest.iloc[-1]
# Out:
# country                        Luxembourg
# adjusted_satisfaction                  66
# avg_satisfaction                      7.7
# std_satisfaction                     1.76
# avg_income                      26182.275
# median_income                    22240.23
# income_inequality                   31.95
# region                   'Western Europe'
# happyScore                          6.946
# GDP                               1.56391
# country.1                      Luxembourg
# Name: 61, dtype: object

# %%
richest.iloc[0:4]
# Out:
#            country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 49           Italy                     57               6.6              1.81
# 44         Ireland                     64               7.5              1.85
# 90          Sweden                     67               7.8              1.72
# 36  United Kingdom                     60               7.1              1.98
#
#     avg_income  median_income  income_inequality            region  \
# 49   15437.595      13163.070           34.12625  'Western Europe'
# 44   16657.770      13823.160           32.41875  'Western Europe'
# 90   17032.755      15166.605           26.95000  'Western Europe'
# 36   17099.550      14172.735           34.43250  'Western Europe'
#
#     happyScore      GDP       country.1
# 49       5.948  1.25114           Italy
# 44       6.940  1.33596         Ireland
# 90       7.364  1.33171          Sweden
# 36       6.867  1.26637  United Kingdom

# %%
import numpy as np

# %%
rich_mean=np.mean(richest['avg_income'])
rich_mean
# Out:
# 19266.68075388889

# %%
all_mean=np.mean(data['avg_income'])
all_mean
# Out:
# 6442.751416180181

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
In [3]: s = pd.Series([1, 3, 5, np.nan, 6, 8])

In [4]: s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
richest
# Out:
#             country  adjusted_satisfaction  avg_satisfaction  \
# 49            Italy                     57               6.6
# 44          Ireland                     64               7.5
# 90           Sweden                     67               7.8
# 36   United Kingdom                     60               7.1
# 7           Belgium                     63               7.2
# 33          Finland                     70               7.9
# 27          Denmark                     74               8.4
# 34           France                     52               6.4
# 76      Netherlands                     69               7.6
# 48          Iceland                     71               8.1
# 25          Germany                     61               7.2
# 3           Austria                     59               7.2
# 4         Australia                     65               7.6
# 16           Canada                     69               8.0
# ...

# %%
plt.scatter(richest['avg_income'],richest['happyScore'])
plt.text(richest.iloc[0]['avg_income'],
         richest.iloc[0]['happyScore'],
         richest.iloc[0]['country'])
# Out:
# Text(15437.595, 5.948, 'Italy')

# %%
import matplotlib.pyplot as plt

# Plot your scatter plot first
plt.scatter(richest['avg_income'], richest['happyScore'])

# Add text annotations
for k, row in richest.iterrows():
    plt.text(row['avg_income'], row['happyScore'], row['country'], fontsize=8)

# Adjust the plot size and limits
plt.gcf().set_size_inches(10, 6)
plt.xlim(0, richest['avg_income'].max() + 1)
plt.ylim(0, richest['happyScore'].max() + 1)

# Display the plot
plt.show()

# %%
plt.scatter(income,happy, s=ineq*10, alpha=0.25 )
plt.xlabel('income')
plt.ylabel('happy score')
# Out:
# Text(0, 0.5, 'happy score')

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
income_happy=np.column_stack((income,happy))
income_happy
# Out:
# array([[2.09676000e+03, 4.35000000e+00],
#        [1.44888000e+03, 4.03300000e+00],
#        [7.10112000e+03, 6.57400000e+00],
#        [1.94570400e+04, 7.20000000e+00],
#        [1.99170000e+04, 7.28400000e+00],
#        [3.38160000e+03, 5.21200000e+00],
#        [1.26534000e+03, 4.69400000e+00],
#        [1.71685050e+04, 6.93700000e+00],
#        [8.70840000e+02, 3.58700000e+00],
#        [5.35482000e+03, 4.21800000e+00],
#        [5.72880000e+02, 2.90500000e+00],
#        [9.89040000e+02, 3.34000000e+00],
#        [3.98571000e+03, 5.89000000e+00],
#        [5.56723500e+03, 6.98300000e+00],
#        [3.48468000e+03, 4.33200000e+00],
#        [5.45393333e+03, 5.81300000e+00],
#        [2.01907800e+04, 7.42700000e+00],
#        [2.34000400e+04, 7.58700000e+00],
#        [7.55799000e+03, 6.67000000e+00],
#        [1.49052000e+03, 4.25200000e+00],
#        [2.67364286e+03, 5.14000000e+00],
#        [4.61806286e+03, 6.47700000e+00],
#        [6.90146667e+03, 7.22600000e+00],
# ...

# %%
km_res=KMeans(n_clusters=3).fit(income_happy)

plt.scatter(income,happy)
plt.scatter(cluster[:,0],cluster[:,1],s=1000)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[184], line 4
#       1 km_res=KMeans(n_clusters=3).fit(income_happy)
#       3 plt.scatter(income,happy)
# ----> 4 plt.scatter(cluster[:,0],cluster[:,1],s=1000)
#
# NameError: name 'cluster' is not defined

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


km_res = KMeans(n_clusters=2).fit(income_happy)


cluster_centers = km_res.cluster_centers_


plt.scatter(income, happy)


plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=1000)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
km_res.cluster_centers_
# Out:
# array([[1.75003154e+04, 6.84691667e+00],
#        [3.39238895e+03, 5.02880460e+00]])
