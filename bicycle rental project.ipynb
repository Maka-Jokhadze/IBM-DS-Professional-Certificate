# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,5]

# %% [markdown]
# ### Phase 1: Get data

# %%
bike_df=pd.read_csv('day.csv')
bike_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
# გადაგვყავს dtdate რიცხვების ფორმატში ისე როგორც სხვა მონაცემები წერია
#რადგან ეს მონაცემი 'string' არის. დაამატებს ახალ ხაზს-date
bike_df['date']=pd.to_datetime(bike_df['dteday'])
bike_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %% [markdown]
# ### Phase 2: Play with data

# %%
plt.scatter(bike_df['date'],bike_df['cnt'],c=bike_df['weathersit'])

# %%
# ვითვლიტ სასუალოდ რამდენი ველოსიპედი ქირავდება გარკვეული ამინდების დროს 
#1-კარგი ამინდი
#2 სასუალო ამინდი
#3-ცუდი ამინდი

# %%
bike_df[bike_df['weathersit']==1]['cnt'].mean()
# Out:
# 4876.7861771058315

# %%
bike_df[bike_df['weathersit']==2]['cnt'].mean()
# Out:
# 4035.862348178138

# %%
bike_df[bike_df['weathersit']==3]['cnt'].mean()
# Out:
# 1803.2857142857142

# %%
#ვაკეთებთ კიდევ ერთ გარფიკს სადაც X-ი იქნება ტემპერატურა
#(ტემპერატურა ნორმალიზებულია 0-1)
#და Y-ი იქნება რაოდენობა, atemp-apparent temperture

# %%
plt.scatter(bike_df['atemp'],bike_df['cnt'])

# %%
bike_df[['cnt','atemp']].corr()
# Out:
#             cnt     atemp
# cnt    1.000000  0.631066
# atemp  0.631066  1.000000

# %%
bike_df[['cnt','temp']].corr()
# Out:
#            cnt      temp
# cnt   1.000000  0.627494
# temp  0.627494  1.000000

# %%
#აქ ჩანს რომ ტემპერატურა რომელიც იგრძნობა გარეთ უფრო მეტად 
#აქვს კორელაცია ველოსიპეტების გაქირავების რაოდენობასტთან ვიდრე 
# ჩვულებრივ ტემპერატურას

# %%
#ჩავყრით ყველას და დავინახავთ ყველას კორელაციას რა ახდენს გავლენას
#weathersit -ნიშნავს ამინდის მდგომარეობას მაგ: ღრუბლიანი , წვიმიანი, მზიანი და ა.შ
bike_df[['cnt','atemp','temp', 'hum','windspeed','weathersit']].corr()
# Out:
#                  cnt     atemp      temp       hum  windspeed  weathersit
# cnt         1.000000  0.631066  0.627494 -0.100659  -0.234545   -0.297391
# atemp       0.631066  1.000000  0.991702  0.139988  -0.183643   -0.121583
# temp        0.627494  0.991702  1.000000  0.126963  -0.157944   -0.120602
# hum        -0.100659  0.139988  0.126963  1.000000  -0.248489    0.591045
# windspeed  -0.234545 -0.183643 -0.157944 -0.248489   1.000000    0.039511
# weathersit -0.297391 -0.121583 -0.120602  0.591045   0.039511    1.000000

# %%
#აქედან ჩანს რომ ძირითადად მხოლოდ ის ტემპერატურა მოქმედებს
#რაოდენობაზე-გაქირავებაზე არის შეგრძნებითი ტემპერატურა,
#ყველა დანარჩენი არ მოქმედებს

# %% [markdown]
# # Phase 3: Learn
# * Linear Regression

# %%
from pylab import*

# %%
#ეს არის მაგალითი წრფივი რეგრესიის ასახსნელად და არა პროექტის მონაცემების
#25% გათვალისწინებულია ცდომილება

# %%
#generate the data
x=arange(50)
np.random.seed(10)
y=2*x+1+25*np.random.rand(len(x))
scatter(x,y)

# %% [markdown]
# ### ვუბრუნდებით პროექტს

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(bike_df['atemp'],bike_df['cnt'])
plt.plot(bike_df['atemp'], lr.predict(bike_df['atemp'].values.reshape(-1,1)), c='red')

# %%
#ესენი ვერ გავიგე რატომ აიღო 1 მონაცემი მანამდე და მეორე შემდეგ
#ჩემი აზრით :
#მოცემულია 2011-2013 წლები , აიღო ამათი შუა თარიღი და რაც მანამდე იყო დაადო
#ზევიდან მეორე ნაწილს რომ ენახა რამდენად ემთხვევა, ან ასევე გააკეტა პრედიქშენი
#რამდენად დაემთხვეოდა ის პირველ და მეორე ნაწილს :
#1ლი  მონაცემი არის გავლილი და მეორე პრედიქშენის
# თუ რას უნდა ველოდოთ

training_set=bike_df[bike_df['date']<'2012-06-01']
validation_set=bike_df[bike_df['date']>='2012-06-01']

training_inputs=training_set[['atemp','workingday','hum','weathersit','windspeed']].values
training_outputs=training_set[['cnt']].values

validation_inputs=validation_set[['atemp','workingday','hum','weathersit','windspeed']].values
validation_outputs=validation_set[['cnt']].values

lr=LinearRegression()
lr.fit(training_inputs,training_outputs)



plt.scatter(training_set['date'],training_set['cnt'])
plt.scatter(training_set['date'],lr.predict(training_inputs))
plt.show()

rmse = np.sqrt(((lr.predict(validation_inputs) - validation_outputs)**2).mean())
rmse
# Out:
# 2139.201362460237

# %%
plt.scatter(validation_set['date'],validation_set['cnt'])
plt.scatter(validation_set['date'],lr.predict(validation_inputs))
plt.show()
